# %% [markdown]
# # 東証 上場銘柄一覧
#
# ソース: [その他統計資料 | 日本取引所グループ](https://www.jpx.co.jp/markets/statistics-equities/misc/01.html)

# %%
import pandas as pd

# %%
df = pd.read_excel("./data/jpx/data_j.xls")
df
# Out:
#             日付   コード                                   銘柄名       市場・商品区分  \
# 0     20240329  1301                                    極洋    プライム（内国株式）
# 1     20240329  1305                ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）       ETF・ETN
# 2     20240329  1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信       ETF・ETN
# 3     20240329  1308                     上場インデックスファンドＴＯＰＩＸ       ETF・ETN
# 4     20240329  1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信       ETF・ETN
# ...        ...   ...                                   ...           ...
# 4349  20240329  9993                                  ヤマザワ  スタンダード（内国株式）
# 4350  20240329  9994                                   やまや  スタンダード（内国株式）
# 4351  20240329  9995                                 グローセル    プライム（内国株式）
# 4352  20240329  9996                                 サトー商会  スタンダード（内国株式）
# 4353  20240329  9997                                  ベルーナ    プライム（内国株式）
#
#      33業種コード  33業種区分 17業種コード 17業種区分 規模コード           規模区分
# 0         50  水産・農林業       1     食品     7  TOPIX Small 2
# 1          -       -       -      -     -              -
# 2          -       -       -      -     -              -
# 3          -       -       -      -     -              -
# 4          -       -       -      -     -              -
# ...      ...     ...     ...    ...   ...            ...
# 4349    6100     小売業      14     小売     7  TOPIX Small 2
# 4350    6100     小売業      14     小売     7  TOPIX Small 2
# 4351    6050     卸売業      13  商社・卸売     7  TOPIX Small 2
# 4352    6050     卸売業      13  商社・卸売     -              -
# 4353    6100     小売業      14     小売     6  TOPIX Small 1
#
# [4354 rows x 10 columns]

# %%
for row in df.itertuples(index=False):
    row

# %%
row
# Out:
# Pandas(日付=20240329, コード=9997, 銘柄名='ベルーナ', _3='プライム（内国株式）', _4=6100, _5='小売業', _6=14, _7='小売', 規模コード=6, 規模区分='TOPIX Small 1')
