# %% [markdown]
# # EPSG コード

# %%
from pathlib import Path
from collections import Counter

from pyproj import CRS
from pyproj.database import get_authorities, get_codes
from tqdm import tqdm

# %% [markdown]
# ## pyproj からの一覧取得

# %%
authorities = get_authorities()
authorities
# Out:
# ['EPSG', 'ESRI', 'IAU_2015', 'IGNF', 'NKG', 'OGC', 'PROJ']

# %%
epsg_codes = {}

for code in tqdm(get_codes("EPSG", "CRS")):
    crs = CRS.from_epsg(code)
    epsg_codes[code] = {
        "name": crs.name,
        "area_of_use": crs.area_of_use.name,
        "coordinate_operation": (
            crs.coordinate_operation.name if crs.coordinate_operation else None
        ),
        "datum": crs.datum.name if crs.datum else None,
    }

epsg_codes
# Out:
# 100%|██████████| 6934/6934 [00:03<00:00, 2068.25it/s]
# {'10150': {'name': 'MSL UK & Ireland VORF08 depth',
#   'area_of_use': 'Ireland and United Kingdom (UK) (including Isle of Man and Channel Islands) - inshore, nearshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'Mean Sea Level UK & Ireland VORF08'},
#  '10151': {'name': 'CD UK & Ireland VORF08 depth',
#   'area_of_use': 'Ireland and United Kingdom (UK) (including Isle of Man and Channel Islands) - inshore, nearshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'Chart Datum UK & Ireland VORF08'},
#  '10156': {'name': 'ETRS89 + MSL UK & Ireland VORF08 depth',
#   'area_of_use': 'Ireland and United Kingdom (UK) (including Isle of Man and Channel Islands) - inshore, nearshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'European Terrestrial Reference System 1989 ensemble'},
#  '10157': {'name': 'ETRS89 + CD UK & Ireland VORF08 depth',
#   'area_of_use': 'Ireland and United Kingdom (UK) (including Isle of Man and Channel Islands) - inshore, nearshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'European Terrestrial Reference System 1989 ensemble'},
#  '10158': {'name': 'S34J-IRF',
#   'area_of_use': 'Denmark - Jutland and Funen - onshore.',
#   'coordinate_operation': None,
#   'datum': 'System 34 Jylland Intermediate Datum'},
#  '10160': {'name': 'S34J reconstruction east-orientated',
#   'area_of_use': 'Denmark - Jutland and Funen - onshore.',
#   'coordinate_operation': 'S34-reconstruction',
#   'datum': 'System 34 Jylland Intermediate Datum'},
#  '10162': {'name': 'JGD2011 / Japan Plane Rectangular CS I + JGD2011 (vertical) height',
#   'area_of_use': 'Japan - onshore - Kyushu west of approximately 130°E - Nagasaki-ken',
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10163': {'name': 'JGD2011 / Japan Plane Rectangular CS II + JGD2011 (vertical) height',
#   'area_of_use': 'Japan - onshore - Kyushu east of approximately 130°E - Fukuoka-ken; Saga-ken; Kumamoto-ken; Oita-ken; Miyazaki-ken; Kagoshima-ken on Kyushu (except for area within Japan Plane Rectangular Coordinate System zone I).',
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10164': {'name': 'JGD2011 / Japan Plane Rectangular CS III + JGD2011 (vertical) height',
#   'area_of_use': "Japan - onshore - Honshu west of approximately 133°15'E - Yamaguchi-ken; Shimane-ken; Hiroshima-ken.",
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10165': {'name': 'JGD2011 / Japan Plane Rectangular CS IV + JGD2011 (vertical) height',
#   'area_of_use': 'Japan - onshore - Shikoku - Kagawa-ken; Ehime-ken; Tokushima-ken; Kochi-ken.',
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10166': {'name': 'JGD2011 / Japan Plane Rectangular CS V + JGD2011 (vertical) height',
#   'area_of_use': "Japan - onshore - Honshu between approximately 133°15'E and 135°10'E - Hyogo-ken; Tottori-ken; Okayama-ken.",
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10167': {'name': 'JGD2011 / Japan Plane Rectangular CS VI + JGD2011 (vertical) height',
#   'area_of_use': "Japan - onshore - Honshu between approximately 135°10'E and 136°45'E - Kyoto-fu; Osaka-fu; Fukui-ken; Shiga-ken; Mie-ken; Nara-ken; Wakayama-ken.",
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10168': {'name': 'JGD2011 / Japan Plane Rectangular CS VII + JGD2011 (vertical) height',
#   'area_of_use': "Japan - onshore - Honshu between approximately 136°15'E and 137°45'E - Ishikawa-ken; Toyama-ken; Gifu-ken; Aichi-ken.",
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10169': {'name': 'JGD2011 / Japan Plane Rectangular CS VIII + JGD2011 (vertical) height',
#   'area_of_use': "Japan - onshore - Honshu between approximately 137°45'E and 139°E - Niigata-ken on Honshu; Nagano-ken; Yamanashi-ken; Shizuoka-ken.",
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10170': {'name': 'JGD2011 / Japan Plane Rectangular CS IX + JGD2011 (vertical) height',
#   'area_of_use': 'Japan - onshore - Honshu - Tokyo-to. (Excludes offshore island areas of Tokyo-to).',
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10171': {'name': 'JGD2011 / Japan Plane Rectangular CS X + JGD2011 (vertical) height',
#   'area_of_use': 'Japan - onshore - Honshu north of 38°N approximately - Aomori-ken; Akita-ken; Yamagata-ken; Iwate-ken; Miyagi-ken.',
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10172': {'name': 'JGD2011 / Japan Plane Rectangular CS XI + JGD2011 (vertical) height',
#   'area_of_use': 'Japan - onshore - Hokkaido west of approximately 141°E - Otaru city; Usu-gun and Abuta-gun of Iburi-shicho; Hiyama-shicho; Shiribeshi-shicho; Oshima-shicho.',
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10173': {'name': 'JGD2011 / Japan Plane Rectangular CS XII + JGD2011 (vertical) height',
#   'area_of_use': 'Japan - onshore - Hokkaido between approximately 141°E and 143°E - Sapporo city; Asahikawa city; Wakkanai city; Rumoi city; Bibai city; Yubari city; Iwamizawa city; Tomakomai city; Muroran city; Shibetsu city; Nayoro city; Ashibetsu city; Akabira city; Mikasa city; Takikawa city; Sunagawa city; Ebetsu city; Chitose city; Utashinai city; Fukagawa city; Monbetsu city; Furano city; Noboribetsu city; Eniwa city; Ishikari-shicho; Monbetsu-gun of Abashiri-shicho; Kamikawa-shicho; Soya-shicho; Hidaka-shicho; Iburi-shicho (except Usu-gun and Abuta-gun); Sorachi-shicho; Rumoi-shicho.',
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10174': {'name': 'JGD2011 / Japan Plane Rectangular CS XIII + JGD2011 (vertical) height',
#   'area_of_use': 'Japan - onshore - Hokkaido east of approximately 143°E - Kitami city; Obihiro city; Kushiro city; Abashiri city; Nemuro city; Nemuro-shicho; Kushiro-shicho; Abashiri-shicho (except Monbetsu-gun); Tokachi-shicho.',
#   'coordinate_operation': None,
#   'datum': 'Japanese Geodetic Datum 2011'},
#  '10175': {'name': 'DoPw22-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Dovey Junction to Pwllheli.',
#   'coordinate_operation': None,
#   'datum': 'DoPw22 Intermediate Reference Frame'},
#  '10176': {'name': 'IGS20',
#   'area_of_use': "World: Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Anguilla, Antarctica, Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belgium, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Bonaire, Saint Eustasius and Saba, Bosnia and Herzegovina, Botswana, Bouvet Island, Brazil, British Indian Ocean Territory, British Virgin Islands, Brunei Darussalam, Bulgaria, Burkina Faso, Burundi, Cambodia, Cameroon, Canada, Cape Verde, Cayman Islands, Central African Republic, Chad, Chile, China, Christmas Island, Cocos (Keeling) Islands, Comoros, Congo, Cook Islands, Costa Rica, Côte d'Ivoire (Ivory Coast), Croatia, Cuba, Curacao, Cyprus, Czechia, Denmark, Djibouti, Dominica, Dominican Republic, East Timor, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Eswatini (Swaziland), Ethiopia, Falkland Islands (Malvinas), Faroe Islands, Fiji, Finland, France, French Guiana, French Polynesia, French Southern Territories, Gabon, Gambia, Georgia, Germany, Ghana, Gibraltar, Greece, Greenland, Grenada, Guadeloupe, Guam, Guatemala, Guinea, Guinea-Bissau, Guyana, Haiti, Heard Island and McDonald Islands, Holy See (Vatican City State), Honduras, China - Hong Kong, Hungary, Iceland, India, Indonesia, Islamic Republic of Iran, Iraq, Ireland, Israel, Italy, Jamaica, Japan, Jordan, Kazakhstan, Kenya, Kiribati, Democratic People's Republic of Korea (North Korea), Republic of Korea (South Korea), Kosovo, Kuwait, Kyrgyzstan, Lao People's Democratic Republic (Laos), Latvia, Lebanon, Lesotho, Liberia, Libyan Arab Jamahiriya, Liechtenstein, Lithuania, Luxembourg, China - Macao, Madagascar, Malawi, Malaysia, Maldives, Mali, Malta, Marshall Islands, Martinique, Mauritania, Mauritius, Mayotte, Mexico, Federated States of Micronesia, Monaco, Mongolia, Montenegro, Montserrat, Morocco, Mozambique, Myanmar (Burma), Namibia, Nauru, Nepal, Netherlands, New Caledonia, New Zealand, Nicaragua, Niger, Nigeria, Niue, Norfolk Island, North Macedonia, Northern Mariana Islands, Norway, Oman, Pakistan, Palau, Panama, Papua New Guinea (PNG), Paraguay, Peru, Philippines, Pitcairn, Poland, Portugal, Puerto Rico, Qatar, Reunion, Romania, Russian Federation, Rwanda, St Barthelemy, St Kitts and Nevis, St Helena, Ascension and Tristan da Cunha, St Lucia, St Martin, St Pierre and Miquelon, Saint Vincent and the Grenadines, Samoa, San Marino, Sao Tome and Principe, Saudi Arabia, Senegal, Serbia, Seychelles, Sierra Leone, Singapore, Slovakia (Slovak Republic), Slovenia, St Maarten, Solomon Islands, Somalia, South Africa, South Georgia and the South Sandwich Islands, South Sudan, Spain, Sri Lanka, Sudan, Suriname, Svalbard and Jan Mayen, Sweden, Switzerland, Syrian Arab Republic, Taiwan, Tajikistan, United Republic of Tanzania, Thailand, The Democratic Republic of the Congo (Zaire), Togo, Tokelau, Tonga, Trinidad and Tobago, Tunisia, Türkiye (Turkey), Turkmenistan, Turks and Caicos Islands, Tuvalu, Uganda, Ukraine, United Arab Emirates (UAE), United Kingdom (UK), United States (USA), United States Minor Outlying Islands, Uruguay, Uzbekistan, Vanuatu, Venezuela, Vietnam, US Virgin Islands, Wallis and Futuna, Western Sahara, Yemen, Zambia, Zimbabwe.",
#   'coordinate_operation': None,
#   'datum': 'IGS20'},
#  '10177': {'name': 'IGS20',
#   'area_of_use': 'World.',
#   'coordinate_operation': None,
#   'datum': 'IGS20'},
#  '10178': {'name': 'IGS20',
#   'area_of_use': 'World.',
#   'coordinate_operation': None,
#   'datum': 'IGS20'},
#  '10183': {'name': 'DoPw22 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Dovey Junction to Pwllheli.',
#   'coordinate_operation': 'DoPw22-TM',
#   'datum': 'DoPw22 Intermediate Reference Frame'},
#  '10184': {'name': 'DoPw22 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Dovey Junction to Pwllheli.',
#   'coordinate_operation': None,
#   'datum': 'DoPw22 Intermediate Reference Frame'},
#  '10185': {'name': 'ShAb07-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Shrewsbury to Aberystwyth.',
#   'coordinate_operation': None,
#   'datum': 'ShAb07 Intermediate Reference Frame'},
#  '10188': {'name': 'ShAb07 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Shrewsbury to Aberystwyth.',
#   'coordinate_operation': 'ShAb07-TM',
#   'datum': 'ShAb07 Intermediate Reference Frame'},
#  '10189': {'name': 'ShAb07 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Shrewsbury to Aberystwyth.',
#   'coordinate_operation': None,
#   'datum': 'ShAb07 Intermediate Reference Frame'},
#  '10190': {'name': 'NGA 2022 height',
#   'area_of_use': 'Algeria - onshore.',
#   'coordinate_operation': None,
#   'datum': "Nivellement General de l'Algerie 2022"},
#  '10191': {'name': 'CNH22-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Crewe via Chester to Holyhead.',
#   'coordinate_operation': None,
#   'datum': 'CNH22 Intermediate Reference Frame'},
#  '10194': {'name': 'CNH22 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Crewe via Chester to Holyhead.',
#   'coordinate_operation': 'CNH22-LCC',
#   'datum': 'CNH22 Intermediate Reference Frame'},
#  '10195': {'name': 'CNH22 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Crewe via Chester to Holyhead.',
#   'coordinate_operation': None,
#   'datum': 'CNH22 Intermediate Reference Frame'},
#  '10196': {'name': 'CWS13-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from from Chester via Wrexham to Shrewsbury.',
#   'coordinate_operation': None,
#   'datum': 'CWS13 Intermediate Reference Frame'},
#  '10199': {'name': 'CWS13 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from from Chester via Wrexham to Shrewsbury.',
#   'coordinate_operation': 'CWS13-TM',
#   'datum': 'CWS13 Intermediate Reference Frame'},
#  '10200': {'name': 'CWS13 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from from Chester via Wrexham to Shrewsbury.',
#   'coordinate_operation': None,
#   'datum': 'CWS13 Intermediate Reference Frame'},
#  '10204': {'name': 'DIBA15-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Didcot to Banbury.',
#   'coordinate_operation': None,
#   'datum': 'DIBA15 Intermediate Reference Frame'},
#  '10207': {'name': 'DIBA15 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Didcot to Banbury.',
#   'coordinate_operation': 'DIBA15-TM',
#   'datum': 'DIBA15 Intermediate Reference Frame'},
#  '10208': {'name': 'DIBA15 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Didcot to Banbury.',
#   'coordinate_operation': None,
#   'datum': 'DIBA15 Intermediate Reference Frame'},
#  '10209': {'name': 'GWPBS22-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from London (Paddington) to Swansea.',
#   'coordinate_operation': None,
#   'datum': 'GWPBS22 Intermediate Reference Frame'},
#  '10212': {'name': 'GWPBS22 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from London (Paddington) to Swansea.',
#   'coordinate_operation': 'GW22-LCC',
#   'datum': 'GWPBS22 Intermediate Reference Frame'},
#  '10213': {'name': 'GWPBS22 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from London (Paddington) to Swansea.',
#   'coordinate_operation': None,
#   'datum': 'GWPBS22 Intermediate Reference Frame'},
#  '10214': {'name': 'GWWAB22-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail routes around Cardiff and the valleys.',
#   'coordinate_operation': None,
#   'datum': 'GWWAB22 Intermediate Reference Frame'},
#  '10217': {'name': 'GWWAB22 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail routes around Cardiff and the valleys.',
#   'coordinate_operation': 'GW22-LCC',
#   'datum': 'GWWAB22 Intermediate Reference Frame'},
#  '10218': {'name': 'GWWAB22 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail routes around Cardiff and the valleys.',
#   'coordinate_operation': None,
#   'datum': 'GWWAB22 Intermediate Reference Frame'},
#  '10219': {'name': 'GWWWA22-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail routes from Swansea to Pembroke Dock, Milford Haven and Fishguard.',
#   'coordinate_operation': None,
#   'datum': 'GWWWA22 Intermediate Reference Frame'},
#  '10222': {'name': 'GWWWA22 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail routes from Swansea to Pembroke Dock, Milford Haven and Fishguard.',
#   'coordinate_operation': 'GW22-LCC',
#   'datum': 'GWWWA22 Intermediate Reference Frame'},
#  '10223': {'name': 'GWWWA22 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail routes from Swansea to Pembroke Dock, Milford Haven and Fishguard.',
#   'coordinate_operation': None,
#   'datum': 'GWWWA22 Intermediate Reference Frame'},
#  '10224': {'name': 'MALS09-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from London (Marylebone) to Leamington Spa.',
#   'coordinate_operation': None,
#   'datum': 'MALS09 Intermediate Reference Frame'},
#  '10227': {'name': 'MALS09 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from London (Marylebone) to Leamington Spa.',
#   'coordinate_operation': 'MALS09-TM',
#   'datum': 'MALS09 Intermediate Reference Frame'},
#  '10228': {'name': 'MALS09 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from London (Marylebone) to Leamington Spa.',
#   'coordinate_operation': None,
#   'datum': 'MALS09 Intermediate Reference Frame'},
#  '10229': {'name': 'OxWo08-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Oxford to Worcester.',
#   'coordinate_operation': None,
#   'datum': 'OxWo08 Intermediate Reference Frame'},
#  '10235': {'name': 'OxWo08 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Oxford to Worcester.',
#   'coordinate_operation': 'OxWo08-TM',
#   'datum': 'OxWo08 Intermediate Reference Frame'},
#  '10236': {'name': 'OxWo08 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Oxford to Worcester.',
#   'coordinate_operation': None,
#   'datum': 'OxWo08 Intermediate Reference Frame'},
#  '10237': {'name': 'SYC20-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Shrewsbury to Crewe.',
#   'coordinate_operation': None,
#   'datum': 'SYC20 Intermediate Reference Frame'},
#  '10240': {'name': 'SYC20 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Shrewsbury to Crewe.',
#   'coordinate_operation': 'SYC20-TM',
#   'datum': 'SYC20 Intermediate Reference Frame'},
#  '10241': {'name': 'SYC20 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Shrewsbury to Crewe.',
#   'coordinate_operation': None,
#   'datum': 'SYC20 Intermediate Reference Frame'},
#  '10245': {'name': 'Slovenia 1996 + SVS2010 height',
#   'area_of_use': 'Slovenia - onshore.',
#   'coordinate_operation': None,
#   'datum': 'Slovenia Geodetic Datum 1996'},
#  '10246': {'name': 'Slovenia 1996 / Slovene National Grid + SVS2010 height',
#   'area_of_use': 'Slovenia - onshore.',
#   'coordinate_operation': None,
#   'datum': 'Slovenia Geodetic Datum 1996'},
#  '10249': {'name': 'S34S-IRF',
#   'area_of_use': 'Denmark - Zealand and Lolland (onshore).',
#   'coordinate_operation': None,
#   'datum': 'System 34 Sjaelland Intermediate Datum'},
#  '10250': {'name': 'S34S reconstruction east-orientated',
#   'area_of_use': 'Denmark - Zealand and Lolland (onshore).',
#   'coordinate_operation': 'S34-reconstruction',
#   'datum': 'System 34 Sjaelland Intermediate Datum'},
#  '10252': {'name': 'S45B-IRF',
#   'area_of_use': 'Denmark - Bornholm onshore.',
#   'coordinate_operation': None,
#   'datum': 'System 45 Bornholm Intermediate Datum'},
#  '10254': {'name': 'S45B reconstruction east-orientated',
#   'area_of_use': 'Denmark - Bornholm onshore.',
#   'coordinate_operation': 'S45B-reconstruction',
#   'datum': 'System 45 Bornholm Intermediate Datum'},
#  '10256': {'name': 'GS-IRF',
#   'area_of_use': 'Denmark - onshore Jutland, Funen, Zealand and Lolland.',
#   'coordinate_operation': None,
#   'datum': 'Generalstabens System Intermediate Datum'},
#  '10258': {'name': 'GS reconstruction east-orientated',
#   'area_of_use': 'Denmark - onshore Jutland, Funen, Zealand and Lolland.',
#   'coordinate_operation': 'Generalstabens System LCC',
#   'datum': 'Generalstabens System Intermediate Datum'},
#  '10260': {'name': 'GSB-IRF',
#   'area_of_use': 'Denmark - Bornholm onshore.',
#   'coordinate_operation': None,
#   'datum': 'Generalstabens System Bornholm Intermediate Datum'},
#  '10262': {'name': 'GSB reconstruction east-orientated',
#   'area_of_use': 'Denmark - Bornholm onshore.',
#   'coordinate_operation': 'GSB-reconstruction',
#   'datum': 'Generalstabens System Bornholm Intermediate Datum'},
#  '10265': {'name': 'KK-IRF',
#   'area_of_use': 'Denmark - onshore - Copenhagen and surrounding area.',
#   'coordinate_operation': None,
#   'datum': 'Copenhagen Commune Intermediate Datum'},
#  '10266': {'name': 'KK reconstruction east-orientated',
#   'area_of_use': 'Denmark - onshore - Copenhagen and surrounding area.',
#   'coordinate_operation': 'Generalstabens System LCC',
#   'datum': 'Copenhagen Commune Intermediate Datum'},
#  '10268': {'name': 'Ostenfeld-IRF',
#   'area_of_use': 'Denmark - onshore northern Schleswig and surrounding islands (i.e. Jutland south of the pre-1920 border near the Kongea river).',
#   'coordinate_operation': None,
#   'datum': 'Ostenfeld  Intermediate Datum'},
#  '10270': {'name': 'Ostenfeld reconstruction',
#   'area_of_use': 'Denmark - onshore northern Schleswig and surrounding islands (i.e. Jutland south of the pre-1920 border near the Kongea river).',
#   'coordinate_operation': 'Ostenfeld-reconstruction',
#   'datum': 'Ostenfeld  Intermediate Datum'},
#  '10272': {'name': 'SMITB20-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Okehampton to Penstone.',
#   'coordinate_operation': None,
#   'datum': 'SMITB20 Intermediate Reference Frame'},
#  '10275': {'name': 'SMITB20 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Okehampton to Penstone.',
#   'coordinate_operation': 'SMITB20-TM',
#   'datum': 'SMITB20 Intermediate Reference Frame'},
#  '10276': {'name': 'SMITB20 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Okehampton to Penstone.',
#   'coordinate_operation': None,
#   'datum': 'SMITB20 Intermediate Reference Frame'},
#  '10277': {'name': 'RBEPP12-IRF',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Reading via Newbury to Penzance.',
#   'coordinate_operation': None,
#   'datum': 'RBEPP12 Intermediate Reference Frame'},
#  '10280': {'name': 'RBEPP12 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Reading via Newbury to Penzance.',
#   'coordinate_operation': 'RBEPP12-LCC',
#   'datum': 'RBEPP12 Intermediate Reference Frame'},
#  '10281': {'name': 'RBEPP12 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Reading via Newbury to Penzance.',
#   'coordinate_operation': None,
#   'datum': 'RBEPP12 Intermediate Reference Frame'},
#  '10282': {'name': 'ETRS89/DREF91/2016',
#   'area_of_use': 'Germany - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10283': {'name': 'ETRS89/DREF91/2016',
#   'area_of_use': 'Germany - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10284': {'name': 'ETRS89/DREF91/2016',
#   'area_of_use': 'Germany - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10285': {'name': 'ETRS89/DREF91/2016 / 3-degree Gauss-Kruger zone 3',
#   'area_of_use': 'Germany - Hamburg, including Neuwerk, Nigehörn, Scharhörn and surrounding maritime area.',
#   'coordinate_operation': '3-degree Gauss-Kruger zone 3',
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10286': {'name': 'ETRS89/DREF91/2016 / UTM zone 31N (N-zE)',
#   'area_of_use': 'Germany - onshore and offshore west of 6°E.',
#   'coordinate_operation': 'UTM zone 31N with prefix',
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10287': {'name': 'ETRS89/DREF91/2016 / UTM zone 31N (zE-N)',
#   'area_of_use': 'Germany - onshore and offshore west of 6°E.',
#   'coordinate_operation': 'UTM zone 31N with prefix',
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10288': {'name': 'ETRS89/DREF91/2016 / UTM zone 32N (N-zE)',
#   'area_of_use': 'Germany - onshore and offshore between 6°E and 12°E, including Mecklenburg-Vorpommern west of 12°E and Schleswig-Holstein.',
#   'coordinate_operation': 'UTM zone 32N with prefix',
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10289': {'name': 'ETRS89/DREF91/2016 / UTM zone 32N (zE-N)',
#   'area_of_use': 'Germany - onshore and offshore between 6°E and 12°E, including Mecklenburg-Vorpommern west of 12°E and Schleswig-Holstein.',
#   'coordinate_operation': 'UTM zone 32N with prefix',
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10290': {'name': 'ETRS89/DREF91/2016 / UTM zone 33N (N-zE)',
#   'area_of_use': 'Germany - onshore and offshore east of 12°E, including Brandenburg (all state, including that part west of 12°E) and Mecklenburg-Vorpommern east of 12°E.',
#   'coordinate_operation': 'UTM zone 33N with prefix',
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10291': {'name': 'ETRS89/DREF91/2016 / UTM zone 33N (zE-N)',
#   'area_of_use': 'Germany - onshore and offshore east of 12°E, including Brandenburg (all state, including that part west of 12°E) and Mecklenburg-Vorpommern east of 12°E.',
#   'coordinate_operation': 'UTM zone 33N with prefix',
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10293': {'name': 'ETRS89/DREF91/2016 + DHHN2016 height',
#   'area_of_use': 'Germany - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'ETRS89/DREF91 Realization 2016'},
#  '10297': {'name': 'RGSH2020',
#   'area_of_use': 'Algeria - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'Sonatrach Reference Frame 2020'},
#  '10298': {'name': 'RGSH2020',
#   'area_of_use': 'Algeria - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'Sonatrach Reference Frame 2020'},
#  '10299': {'name': 'RGSH2020',
#   'area_of_use': 'Algeria - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'Sonatrach Reference Frame 2020'},
#  '10300': {'name': 'RGNC91-93 (lon-lat)',
#   'area_of_use': 'New Caledonia - onshore and offshore. Isle de Pins, Loyalty Islands, Huon Islands, Belep archipelago, Chesterfield Islands, and Walpole.',
#   'coordinate_operation': None,
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 91-93'},
#  '10303': {'name': 'LKS-2020',
#   'area_of_use': 'Latvia - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'Latvian coordinate system 2020'},
#  '10304': {'name': 'LKS-2020',
#   'area_of_use': 'Latvia - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'Latvian coordinate system 2020'},
#  '10305': {'name': 'LKS-2020',
#   'area_of_use': 'Latvia - onshore and offshore.',
#   'coordinate_operation': None,
#   'datum': 'Latvian coordinate system 2020'},
#  '10306': {'name': 'LKS-2020 / Latvia TM',
#   'area_of_use': 'Latvia - onshore and offshore.',
#   'coordinate_operation': 'Latvian Transverse Mercator',
#   'datum': 'Latvian coordinate system 2020'},
#  '10307': {'name': 'RGNC91-93 (lon-lat)',
#   'area_of_use': 'New Caledonia - onshore and offshore. Isle de Pins, Loyalty Islands, Huon Islands, Belep archipelago, Chesterfield Islands, and Walpole.',
#   'coordinate_operation': None,
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 91-93'},
#  '10308': {'name': 'RGNC15',
#   'area_of_use': 'New Caledonia - onshore and offshore. Isle de Pins, Loyalty Islands, Huon Islands, Belep archipelago, Chesterfield Islands, and Walpole.',
#   'coordinate_operation': None,
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10309': {'name': 'RGNC15',
#   'area_of_use': 'New Caledonia - onshore and offshore. Isle de Pins, Loyalty Islands, Huon Islands, Belep archipelago, Chesterfield Islands, and Walpole.',
#   'coordinate_operation': None,
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10310': {'name': 'RGNC15',
#   'area_of_use': 'New Caledonia - onshore and offshore. Isle de Pins, Loyalty Islands, Huon Islands, Belep archipelago, Chesterfield Islands, and Walpole.',
#   'coordinate_operation': None,
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10311': {'name': 'RGNC15 (lon-lat)',
#   'area_of_use': 'New Caledonia - onshore and offshore. Isle de Pins, Loyalty Islands, Huon Islands, Belep archipelago, Chesterfield Islands, and Walpole.',
#   'coordinate_operation': None,
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10312': {'name': 'RGNC15 (lon-lat)',
#   'area_of_use': 'New Caledonia - onshore and offshore. Isle de Pins, Loyalty Islands, Huon Islands, Belep archipelago, Chesterfield Islands, and Walpole.',
#   'coordinate_operation': None,
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10314': {'name': 'RGNC15 / Lambert New Caledonia 2015',
#   'area_of_use': 'New Caledonia - Belep, Grande Terre, Ile des Pins, Loyalty Islands (Lifou, Mare, Ouvea).',
#   'coordinate_operation': 'Lambert New Caledonia 2015',
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10315': {'name': 'RGNC15 / UTM zone 57S',
#   'area_of_use': 'New Caledonia - west of 162°E onshore and offshore.',
#   'coordinate_operation': 'UTM zone 57S',
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10316': {'name': 'RGNC15 / UTM zone 58S',
#   'area_of_use': 'New Caledonia - between 162°E and 168°E onshore and offshore.',
#   'coordinate_operation': 'UTM zone 58S',
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10317': {'name': 'RGNC15 / UTM zone 59S',
#   'area_of_use': 'New Caledonia - east of 168°E onshore and offshore.',
#   'coordinate_operation': 'UTM zone 59S',
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10318': {'name': 'RGNC15 (lon-lat) + NGNC08 height',
#   'area_of_use': 'New Caledonia - Belep, Grande Terre, Ile des Pins, Loyalty Islands (Lifou, Mare, Ouvea).',
#   'coordinate_operation': None,
#   'datum': 'Reseau Geodesique de Nouvelle Caledonie 2015'},
#  '10326': {'name': 'BH_ETRS89',
#   'area_of_use': 'Bosnia and Herzegovina.',
#   'coordinate_operation': None,
#   'datum': 'BH_ETRS89'},
#  '10327': {'name': 'BH_ETRS89',
#   'area_of_use': 'Bosnia and Herzegovina.',
#   'coordinate_operation': None,
#   'datum': 'BH_ETRS89'},
#  '10328': {'name': 'BH_ETRS89',
#   'area_of_use': 'Bosnia and Herzegovina.',
#   'coordinate_operation': None,
#   'datum': 'BH_ETRS89'},
#  '10329': {'name': 'BH_ETRS89 / TM',
#   'area_of_use': 'Bosnia and Herzegovina.',
#   'coordinate_operation': 'Bosnia and Herzegovina Transverse Mercator',
#   'datum': 'BH_ETRS89'},
#  '10345': {'name': 'Hughes 1980',
#   'area_of_use': 'World.',
#   'coordinate_operation': None,
#   'datum': 'Hughes 1980'},
#  '10346': {'name': 'NSIDC Authalic Sphere',
#   'area_of_use': 'World.',
#   'coordinate_operation': None,
#   'datum': 'NSIDC International 1924 Authalic Sphere'},
#  '10349': {'name': 'ZH Portugal depth',
#   'area_of_use': 'Portugal - offshore.',
#   'coordinate_operation': None,
#   'datum': 'Chart Datum Portugal '},
#  '10352': {'name': 'Formentera height',
#   'area_of_use': 'Spain - Balearic Islands - Formentera - onshore.',
#   'coordinate_operation': None,
#   'datum': 'Formentera'},
#  '10353': {'name': 'Alboran height',
#   'area_of_use': 'Spain - Alboran island - onshore.',
#   'coordinate_operation': None,
#   'datum': 'Alboran'},
#  '10354': {'name': 'Melilla height',
#   'area_of_use': 'Spain - Melilla onshore.',
#   'coordinate_operation': None,
#   'datum': 'Melilla'},
#  '10355': {'name': 'ETRS89 + Formentera height',
#   'area_of_use': 'Spain - Balearic Islands - Formentera - onshore.',
#   'coordinate_operation': None,
#   'datum': 'European Terrestrial Reference System 1989 ensemble'},
#  '10356': {'name': 'ETRS89 + Alboran height',
#   'area_of_use': 'Spain - Alboran island - onshore.',
#   'coordinate_operation': None,
#   'datum': 'European Terrestrial Reference System 1989 ensemble'},
#  '10357': {'name': 'ETRS89 + Melilla height',
#   'area_of_use': 'Spain - Melilla onshore.',
#   'coordinate_operation': None,
#   'datum': 'European Terrestrial Reference System 1989 ensemble'},
#  '10364': {'name': 'Cascais depth',
#   'area_of_use': 'Portugal - mainland - onshore.',
#   'coordinate_operation': None,
#   'datum': 'Cascais'},
#  '10365': {'name': 'KGD2002 + KVD1964 height',
#   'area_of_use': 'Republic of Korea (South Korea) - onshore.',
#   'coordinate_operation': None,
#   'datum': 'Korean Geodetic Datum 2002'},
#  '10370': {'name': 'Cais da Pontinha depth',
#   'area_of_use': 'Portugal - Madeira and Desertas islands - onshore.',
#   'coordinate_operation': None,
#   'datum': 'Cais da Pontinha'},
#  '10371': {'name': 'Cais da Vila depth',
#   'area_of_use': 'Portugal - Porto Santo island (Madeira archipelago) onshore.',
#   'coordinate_operation': None,
#   'datum': 'Cais da Vila'},
#  '10372': {'name': 'Santa Cruz das Flores depth',
#   'area_of_use': 'Portugal - western Azores - Flores island onshore.',
#   'coordinate_operation': None,
#   'datum': 'Santa Cruz das Flores'},
#  '10373': {'name': 'Horta depth',
#   'area_of_use': 'Portugal - central Azores - Faial island onshore.',
#   'coordinate_operation': None,
#   'datum': 'Horta'},
#  '10374': {'name': 'Cais da Madalena depth',
#   'area_of_use': 'Portugal - central Azores - Pico island onshore.',
#   'coordinate_operation': None,
#   'datum': 'Cais da Madalena'},
#  '10375': {'name': 'Cais das Velas depth',
#   'area_of_use': 'Portugal - central Azores - Sao Jorge island onshore.',
#   'coordinate_operation': None,
#   'datum': 'Cais das Velas'},
#  '10376': {'name': 'Santa Cruz da Graciosa depth',
#   'area_of_use': 'Portugal - central Azores - Graciosa island onshore.',
#   'coordinate_operation': None,
#   'datum': 'Santa Cruz da Graciosa'},
#  '10377': {'name': 'Cais da Figueirinha depth',
#   'area_of_use': 'Portugal - central Azores - Terceira island onshore.',
#   'coordinate_operation': None,
#   'datum': 'Cais da Figueirinha'},
#  '10378': {'name': 'Ponta Delgada depth',
#   'area_of_use': 'Portugal - eastern Azores - Sao Miguel island onshore.',
#   'coordinate_operation': None,
#   'datum': 'Ponta Delgada'},
#  '10379': {'name': 'Cais da Vila do Porto depth',
#   'area_of_use': 'Portugal - eastern Azores onshore - Santa Maria, Formigas.',
#   'coordinate_operation': None,
#   'datum': 'Cais da Vila do Porto'},
#  '10412': {'name': 'NAD83(CSRS)v8',
#   'area_of_use': 'Canada - onshore and offshore - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon.',
#   'coordinate_operation': None,
#   'datum': 'North American Datum of 1983 (CSRS) version 8'},
#  '10413': {'name': 'NAD83(CSRS)v8',
#   'area_of_use': 'Canada - onshore and offshore - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon.',
#   'coordinate_operation': None,
#   'datum': 'North American Datum of 1983 (CSRS) version 8'},
#  '10414': {'name': 'NAD83(CSRS)v8',
#   'area_of_use': 'Canada - onshore and offshore - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon.',
#   'coordinate_operation': None,
#   'datum': 'North American Datum of 1983 (CSRS) version 8'},
#  '10448': {'name': 'GDA94 / ALB94',
#   'area_of_use': 'Australia - Western Australia - Albany area onshore below 190m AHD.',
#   'coordinate_operation': 'Albany Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10449': {'name': 'GDA94 / BIO94',
#   'area_of_use': 'Australia - Western Australia - Barrow Island and Onslow area onshore.',
#   'coordinate_operation': 'Barrow Island Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10450': {'name': 'GDA94 / BRO94',
#   'area_of_use': 'Australia - Western Australia - Broome area onshore below 130m AHD.',
#   'coordinate_operation': 'Broome Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10451': {'name': 'GDA94 / BCG94',
#   'area_of_use': 'Australia - Western Australia - Busselton area onshore below 250m AHD.',
#   'coordinate_operation': 'Busselton Coastal Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10452': {'name': 'GDA94 / CARN94',
#   'area_of_use': 'Australia - Western Australia - Carnarvon area onshore.',
#   'coordinate_operation': 'Carnarvon Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10453': {'name': 'GDA94 / COL94',
#   'area_of_use': 'Australia - Western Australia - Collie area between 50m and 310m AHD.',
#   'coordinate_operation': 'Collie Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10454': {'name': 'GDA94 / ESP94',
#   'area_of_use': 'Australia - Western Australia - Esperance area onshore.',
#   'coordinate_operation': 'Esperance Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10455': {'name': 'GDA94 / EXM94',
#   'area_of_use': 'Australia - Western Australia - Exmouth area onshore below 160m AHD.',
#   'coordinate_operation': 'Exmouth Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10456': {'name': 'GDA94 / GCG94',
#   'area_of_use': 'Australia - Western Australia - Geraldton area onshore below 195m AHD.',
#   'coordinate_operation': 'Geraldton Coastal Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10457': {'name': 'GDA94 / GOLD94',
#   'area_of_use': 'Australia - Western Australia - Kalgoorlie area.',
#   'coordinate_operation': 'Goldfields Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10458': {'name': 'GDA94 / JCG94',
#   'area_of_use': 'Australia - Western Australia - Jurien Bay area onshore below 200m AHD.',
#   'coordinate_operation': 'Jurien Coastal Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10459': {'name': 'GDA94 / KALB94',
#   'area_of_use': 'Australia - Western Australia - Kalbarri area onshore.',
#   'coordinate_operation': 'Kalbarri Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10460': {'name': 'GDA94 / KAR94',
#   'area_of_use': 'Australia - Western Australia - Karratha area onshore.',
#   'coordinate_operation': 'Karratha Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10461': {'name': 'GDA94 / KUN94',
#   'area_of_use': 'Australia - Western Australia - Kununurra area onshore below 200m AHD.',
#   'coordinate_operation': 'Kununurra Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10462': {'name': 'GDA94 / LCG94',
#   'area_of_use': 'Australia - Western Australia - Lancelin area onshore below 200m AHD.',
#   'coordinate_operation': 'Lancelin Coastal Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10463': {'name': 'GDA94 / MRCG94',
#   'area_of_use': 'Australia - Western Australia - Margaret River area onshore below 200m AHD.',
#   'coordinate_operation': 'Margaret River Coastal Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10464': {'name': 'GDA94 / PCG94',
#   'area_of_use': 'Australia - Western Australia - Perth area onshore below 165m AHD.',
#   'coordinate_operation': 'Perth Coastal Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10465': {'name': 'GDA94 / PHG94',
#   'area_of_use': 'Australia - Western Australia - Port Hedland area onshore.',
#   'coordinate_operation': 'Port Hedland Grid 1994',
#   'datum': 'Geocentric Datum of Australia 1994'},
#  '10468': {'name': 'COV23-IRF',
#   'area_of_use': 'United Kingdom (UK) - in and around the area of Coventry city centre and the route to Birmingham airport.',
#   'coordinate_operation': None,
#   'datum': 'COV23 Intermediate Reference Frame'},
#  '10471': {'name': 'COV23 Grid',
#   'area_of_use': 'United Kingdom (UK) - in and around the area of Coventry city centre and the route to Birmingham airport.',
#   'coordinate_operation': 'COV23-TM',
#   'datum': 'COV23 Intermediate Reference Frame'},
#  '10472': {'name': 'COV23 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - in and around the area of Coventry city centre and the route to Birmingham airport.',
#   'coordinate_operation': None,
#   'datum': 'COV23 Intermediate Reference Frame'},
#  '11114': {'name': 'MAGNA-SIRGAS 2018 / Colombia Far West zone',
#   'area_of_use': "Colombia - mainland onshore west of 4°30'W of Bogota (approximately 78°35'W of Greenwich).",
#   'coordinate_operation': 'Colombia MAGNA 2018 Far West zone',
#   'datum': 'Marco Geocentrico Nacional de Referencia 2018'},
#  '11115': {'name': 'MAGNA-SIRGAS 2018 / Colombia West zone',
#   'area_of_use': "Colombia - onshore between 4°30'W and 1°30'W of Bogota (approximately 78°35'W and 75°35'W of Greenwich).",
#   'coordinate_operation': 'Colombia MAGNA 2018 West zone',
#   'datum': 'Marco Geocentrico Nacional de Referencia 2018'},
#  '11116': {'name': 'MAGNA-SIRGAS 2018 / Colombia Bogota zone',
#   'area_of_use': "Colombia - onshore between 1°30'W and 1°30'E of Bogota (approximately 75°35'W and 72°35'W of Greenwich).",
#   'coordinate_operation': 'Colombia MAGNA 2018 Bogota zone',
#   'datum': 'Marco Geocentrico Nacional de Referencia 2018'},
#  '11117': {'name': 'MAGNA-SIRGAS 2018 / Colombia East Central zone',
#   'area_of_use': "Colombia - onshore between 1°30'E and 4°30'E of Bogota (approximately 72°35'W and 69°35'W of Greenwich).",
#   'coordinate_operation': 'Colombia MAGNA 2018 East Central zone',
#   'datum': 'Marco Geocentrico Nacional de Referencia 2018'},
#  '11118': {'name': 'MAGNA-SIRGAS 2018 / Colombia East zone',
#   'area_of_use': "Colombia - east of 4°30'E of Bogota (approximately 69°35'W of Greenwich).",
#   'coordinate_operation': 'Colombia MAGNA 2018 East zone',
#   'datum': 'Marco Geocentrico Nacional de Referencia 2018'},
#  '2000': {'name': 'Anguilla 1957 / British West Indies Grid',
#   'area_of_use': 'Anguilla - onshore.',
#   'coordinate_operation': 'British West Indies Grid',
#   'datum': 'Anguilla 1957'},
#  '20000': {'name': 'SVD2006 height',
#   'area_of_use': "Arctic (Norway (Svalbard) onshore and offshore) - between 81°10'N and 76°10'N.",
#   'coordinate_operation': None,
#   'datum': 'Svalbard vertical datum 2006'},
#  '20001': {'name': 'ETRS89 + SVD2006 height',
#   'area_of_use': "Arctic (Norway (Svalbard) onshore and offshore) - between 81°10'N and 76°10'N.",
#   'coordinate_operation': None,
#   'datum': 'European Terrestrial Reference System 1989 ensemble'},
#  '20002': {'name': 'MWC18 Grid',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Manchester via Wigan and Liverpool to Chester.',
#   'coordinate_operation': 'MWC18-TM',
#   'datum': 'MWC18 Intermediate Reference Frame'},
#  '20003': {'name': 'MWC18 Grid + ODN height',
#   'area_of_use': 'United Kingdom (UK) - on or related to the rail route from Manchester via Wigan and Liverpool to Chester.',
#   'coordinate_operation': None,
#   'datum': 'MWC18 Intermediate Reference Frame'},
#  '20004': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 4',
#   'area_of_use': 'Russian Federation - onshore west of 24°E - Kaliningrad.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 4',
#   'datum': 'Pulkovo 1995'},
#  '20005': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 5',
#   'area_of_use': 'Russian Federation - onshore between 24°E and 30°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 5',
#   'datum': 'Pulkovo 1995'},
#  '20006': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 6',
#   'area_of_use': 'Russian Federation - onshore between 30°E and 36°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 6',
#   'datum': 'Pulkovo 1995'},
#  '20007': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 7',
#   'area_of_use': 'Russian Federation - onshore between 36°E and 42°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 7',
#   'datum': 'Pulkovo 1995'},
#  '20008': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 8',
#   'area_of_use': 'Russian Federation - onshore between 42°E and 48°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 8',
#   'datum': 'Pulkovo 1995'},
#  '20009': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 9',
#   'area_of_use': 'Russian Federation - onshore between 48°E and 54°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 9',
#   'datum': 'Pulkovo 1995'},
#  '2001': {'name': 'Antigua 1943 / British West Indies Grid',
#   'area_of_use': 'Antigua island - onshore.',
#   'coordinate_operation': 'British West Indies Grid',
#   'datum': 'Antigua 1943'},
#  '20010': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 10',
#   'area_of_use': 'Russian Federation - onshore between 54°E and 60°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 10',
#   'datum': 'Pulkovo 1995'},
#  '20011': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 11',
#   'area_of_use': 'Russian Federation - onshore between 60°E and 66°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 11',
#   'datum': 'Pulkovo 1995'},
#  '20012': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 12',
#   'area_of_use': 'Russian Federation - onshore between 66°E and 72°E .',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 12',
#   'datum': 'Pulkovo 1995'},
#  '20013': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 13',
#   'area_of_use': 'Russian Federation - onshore between 72°E and 78°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 13',
#   'datum': 'Pulkovo 1995'},
#  '20014': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 14',
#   'area_of_use': 'Russian Federation - onshore between 78°E and 84°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 14',
#   'datum': 'Pulkovo 1995'},
#  '20015': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 15',
#   'area_of_use': 'Russian Federation - onshore between 84°E and 90°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 15',
#   'datum': 'Pulkovo 1995'},
#  '20016': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 16',
#   'area_of_use': 'Russian Federation - onshore between 90°E and 96°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 16',
#   'datum': 'Pulkovo 1995'},
#  '20017': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 17',
#   'area_of_use': 'Russian Federation - onshore between 96°E and 102°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 17',
#   'datum': 'Pulkovo 1995'},
#  '20018': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 18',
#   'area_of_use': 'Russian Federation - onshore between 102°E and 108°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 18',
#   'datum': 'Pulkovo 1995'},
#  '20019': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 19',
#   'area_of_use': 'Russian Federation - onshore between 108°E and 114°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 19',
#   'datum': 'Pulkovo 1995'},
#  '2002': {'name': 'Dominica 1945 / British West Indies Grid',
#   'area_of_use': 'Dominica - onshore.',
#   'coordinate_operation': 'British West Indies Grid',
#   'datum': 'Dominica 1945'},
#  '20020': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 20',
#   'area_of_use': 'Russian Federation - onshore between 114°E and 120°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 20',
#   'datum': 'Pulkovo 1995'},
#  '20021': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 21',
#   'area_of_use': 'Russian Federation - onshore between 120°E and 126°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 21',
#   'datum': 'Pulkovo 1995'},
#  '20022': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 22',
#   'area_of_use': 'Russian Federation - onshore between 126°E and 132°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 22',
#   'datum': 'Pulkovo 1995'},
#  '20023': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 23',
#   'area_of_use': 'Russian Federation - onshore between 132°E and 138°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 23',
#   'datum': 'Pulkovo 1995'},
#  '20024': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 24',
#   'area_of_use': 'Russian Federation - onshore between 138°E and 144°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 24',
#   'datum': 'Pulkovo 1995'},
#  '20025': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 25',
#   'area_of_use': 'Russian Federation - onshore between 144°E and 150°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 25',
#   'datum': 'Pulkovo 1995'},
#  '20026': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 26',
#   'area_of_use': 'Russian Federation - onshore between 150°E and 156°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 26',
#   'datum': 'Pulkovo 1995'},
#  '20027': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 27',
#   'area_of_use': 'Russian Federation - onshore between 156°E and 162°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 27',
#   'datum': 'Pulkovo 1995'},
#  '20028': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 28',
#   'area_of_use': 'Russian Federation - onshore between 162°E and 168°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 28',
#   'datum': 'Pulkovo 1995'},
#  '20029': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 29',
#   'area_of_use': 'Russian Federation - onshore between 168°E and 174°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 29',
#   'datum': 'Pulkovo 1995'},
#  '2003': {'name': 'Grenada 1953 / British West Indies Grid',
#   'area_of_use': 'Grenada and southern Grenadine Islands - onshore.',
#   'coordinate_operation': 'British West Indies Grid',
#   'datum': 'Grenada 1953'},
#  '20030': {'name': 'Pulkovo 1995 / Gauss-Kruger zone 30',
# ...
#   'area_of_use': 'Indonesia - offshore Madura Strait and western Bali Sea.',
#   'coordinate_operation': 'TM 116 SE',
#   'datum': 'World Geodetic System 1984 ensemble'},
#  '23090': {'name': 'ED50 / TM 0 N',
#   'area_of_use': 'United Kingdom (UK) - offshore - North Sea.',
#   'coordinate_operation': 'TM 0 N',
#   'datum': 'European Datum 1950'},
#  '23095': {'name': 'ED50 / TM 5 NE',
#   'area_of_use': 'Netherlands - offshore North Sea.',
#   'coordinate_operation': 'TM 5 NE',
#   'datum': 'European Datum 1950'},
#  '2310': {'name': 'WGS 84 / TM 132 SE',
#   'area_of_use': 'Indonesia - West Papua (formerly Irian Jaya) - Tangguh.',
#   'coordinate_operation': 'TM 132 SE',
#   'datum': 'World Geodetic System 1984 ensemble'},
#  '2311': {'name': 'WGS 84 / TM 6 NE',
#   'area_of_use': 'Nigeria - offshore.',
#   'coordinate_operation': 'TM 6 NE',
#   'datum': 'World Geodetic System 1984 ensemble'},
#  '2312': {'name': 'Garoua / UTM zone 33N',
#   'area_of_use': 'Cameroon - Garoua area.',
#   'coordinate_operation': 'UTM zone 33N',
#   'datum': 'Garoua'},
#  '2313': {'name': 'Kousseri / UTM zone 33N',
#   'area_of_use': "Cameroon - N'Djamena area.",
#   'coordinate_operation': 'UTM zone 33N',
#   'datum': 'Kousseri'},
#  '2314': {'name': 'Trinidad 1903 / Trinidad Grid (ftCla)',
#   'area_of_use': 'Trinidad and Tobago - Trinidad - onshore and offshore.',
#   'coordinate_operation': "Trinidad Grid (Clarke's feet)",
#   'datum': 'Trinidad 1903'},
#  '2315': {'name': 'Campo Inchauspe / UTM zone 19S',
#   'area_of_use': 'Argentina - Tierra del Fuego offshore Atlantic west of 66°W.',
#   'coordinate_operation': 'UTM zone 19S',
#   'datum': 'Campo Inchauspe'},
#  '2316': {'name': 'Campo Inchauspe / UTM zone 20S',
#   'area_of_use': 'Argentina - Tierra del Fuego offshore Atlantic east of 66°W.',
#   'coordinate_operation': 'UTM zone 20S',
#   'datum': 'Campo Inchauspe'},
#  '2317': {'name': 'PSAD56 / ICN Regional',
#   'area_of_use': 'Venezuela - onshore.',
#   'coordinate_operation': 'ICN Regional',
#   'datum': 'Provisional South American Datum 1956'},
#  '2318': {'name': 'Ain el Abd / Aramco Lambert',
#   'area_of_use': 'Saudi Arabia - onshore.',
#   'coordinate_operation': 'Aramco Lambert',
#   'datum': 'Ain el Abd 1970'},
#  '2319': {'name': 'ED50 / TM27',
#   'area_of_use': "Türkiye (Turkey) - west of 28°30'E, onshore.",
#   'coordinate_operation': 'Gauss-Kruger CM 27E',
#   'datum': 'European Datum 1950'},
#  '2320': {'name': 'ED50 / TM30',
#   'area_of_use': "Türkiye (Turkey) - between 28°30'E and 31°30'E, onshore.",
#   'coordinate_operation': '3-degree Gauss-Kruger CM 30E',
#   'datum': 'European Datum 1950'},
#  '2321': {'name': 'ED50 / TM33',
#   'area_of_use': "Türkiye (Turkey) - between 31°30'E and 34°30'E, onshore.",
#   'coordinate_operation': 'Gauss-Kruger CM 33E',
#   'datum': 'European Datum 1950'},
#  '2322': {'name': 'ED50 / TM36',
#   'area_of_use': "Türkiye (Turkey) - between 34°30'E and 37°30'E, onshore.",
#   'coordinate_operation': '3-degree Gauss-Kruger CM 36E',
#   'datum': 'European Datum 1950'},
#  '2323': {'name': 'ED50 / TM39',
#   'area_of_use': "Türkiye (Turkey) - between 37°30'E and 40°30'E, onshore.",
#   'coordinate_operation': 'Gauss-Kruger CM 39E',
#   'datum': 'European Datum 1950'},
#  '23239': {'name': 'Fahud / UTM zone 39N',
#   'area_of_use': 'Oman - onshore west of 54°E.',
#   'coordinate_operation': 'UTM zone 39N',
#   'datum': 'Fahud'},
#  '2324': {'name': 'ED50 / TM42',
#   'area_of_use': "Türkiye (Turkey) - between 40°30'E and 43°30'E, onshore.",
#   'coordinate_operation': '3-degree Gauss-Kruger CM 42E',
#   'datum': 'European Datum 1950'},
#  '23240': {'name': 'Fahud / UTM zone 40N',
#   'area_of_use': 'Oman - mainland onshore east of 54°E.',
#   'coordinate_operation': 'UTM zone 40N',
#   'datum': 'Fahud'},
#  '2325': {'name': 'ED50 / TM45',
#   'area_of_use': "Türkiye (Turkey) - east of 43°30'E.",
#   'coordinate_operation': 'Gauss-Kruger CM 45E',
#   'datum': 'European Datum 1950'},
#  '2326': {'name': 'Hong Kong 1980 Grid System',
#   'area_of_use': 'China - Hong Kong - onshore and offshore.',
#   'coordinate_operation': 'Hong Kong 1980 Grid',
#   'datum': 'Hong Kong 1980'},
#  '2327': {'name': 'Xian 1980 / Gauss-Kruger zone 13',
#   'area_of_use': 'China - west of 78°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 13',
#   'datum': 'Xian 1980'},
#  '2328': {'name': 'Xian 1980 / Gauss-Kruger zone 14',
#   'area_of_use': 'China - between 78°E and 84°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 14',
#   'datum': 'Xian 1980'},
#  '2329': {'name': 'Xian 1980 / Gauss-Kruger zone 15',
#   'area_of_use': 'China - between 84°E and 90°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 15',
#   'datum': 'Xian 1980'},
#  '2330': {'name': 'Xian 1980 / Gauss-Kruger zone 16',
#   'area_of_use': 'China - between 90°E and 96°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 16',
#   'datum': 'Xian 1980'},
#  '23301': {'name': 'NAD83(2011) / ICS83-Freeport (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Carroll, Jo Daviess and Stephenson.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Freeport zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23302': {'name': 'NAD83(2011) / ICS83-Rockford (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Lee, Ogle and Winnebago.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Rockford zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23303': {'name': 'NAD83(2011) / ICS83-Aurora (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Boone, Dekalb, Kane, Kendall and McHenry.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Aurora zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23304': {'name': 'NAD83(2011) / ICS83-Chicago (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Cook, DuPage and Lake.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Chicago zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23305': {'name': 'NAD83(2011) / ICS83-Moline (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - Rock Island county.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Moline zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23306': {'name': 'NAD83(2011) / ICS83-Sterling (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Henry and Whiteside.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Sterling zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23307': {'name': 'NAD83(2011) / ICS83-Ottawa (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Bureau, Grundy, LaSalle and Putnam.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Ottawa zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23308': {'name': 'NAD83(2011) / ICS83-Joliet (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Kankakee and Will.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Joliet zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23309': {'name': 'NAD83(2011) / ICS83-Monmouth (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Henderson, Mercer and Warren.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Monmouth zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '2331': {'name': 'Xian 1980 / Gauss-Kruger zone 17',
#   'area_of_use': 'China - between 96°E and 102°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 17',
#   'datum': 'Xian 1980'},
#  '23310': {'name': 'NAD83(2011) / ICS83-Galesburg (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Fulton, Knox and Stark.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Galesburg zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23311': {'name': 'NAD83(2011) / ICS83-Peoria (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Peoria and Tazewell.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Peoria zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23312': {'name': 'NAD83(2011) / ICS83-Eureka (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Marshall and Woodford.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Eureka zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23313': {'name': 'NAD83(2011) / ICS83-Bloomington (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - McLean county.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Bloomington zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23314': {'name': 'NAD83(2011) / ICS83-Pontiac (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - Livingston county.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Pontiac zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23315': {'name': 'NAD83(2011) / ICS83-Watseka (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Ford and Iroquois.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Watseka zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23316': {'name': 'NAD83(2011) / ICS83-Quincy (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Adams and Hancock.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Quincy zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23317': {'name': 'NAD83(2011) / ICS83-Macomb (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Brown, McDonough and Schuyler.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Macomb zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23318': {'name': 'NAD83(2011) / ICS83-Lincoln (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Cass, Logan, Mason and Menard.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Lincoln zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23319': {'name': 'NAD83(2011) / ICS83-Decatur (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Dewitt, Macon, Moultrie, Piatt and Shelby.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Decatur zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '2332': {'name': 'Xian 1980 / Gauss-Kruger zone 18',
#   'area_of_use': 'China - onshore between 102°E and 108°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 18',
#   'datum': 'Xian 1980'},
#  '23320': {'name': 'NAD83(2011) / ICS83-Champaign (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Champaign and Vermilion.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Champaign zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23321': {'name': 'NAD83(2011) / ICS83-Jacksonville (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Morgan, Pike and Scott.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Jacksonville zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23322': {'name': 'NAD83(2011) / ICS83-Springfield (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - Sangamon county.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Springfield zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23323': {'name': 'NAD83(2011) / ICS83-Charleston (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Coles, Douglas and Edgar.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Charleston zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23324': {'name': 'NAD83(2011) / ICS83-Jerseyville (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Calhoun and Jersey.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Jerseyville zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23325': {'name': 'NAD83(2011) / ICS83-Carlinville (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Greene and Macoupin.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Carlinville zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23326': {'name': 'NAD83(2011) / ICS83-Taylorville (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Christian and Montgomery.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Taylorville zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23327': {'name': 'NAD83(2011) / ICS83-Effingham (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Bond, Effingham and Fayette.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Effingham zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23328': {'name': 'NAD83(2011) / ICS83-Robinson (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Clark, Crawford, Cumberland and Jasper.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Robinson zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23329': {'name': 'NAD83(2011) / ICS83-Belleville (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Madison, Monroe and St Clair.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Belleville zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '2333': {'name': 'Xian 1980 / Gauss-Kruger zone 19',
#   'area_of_use': 'China - onshore between 108°E and 114°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 19',
#   'datum': 'Xian 1980'},
#  '23330': {'name': 'NAD83(2011) / ICS83-Mount Vernon (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Clinton, Jefferson, Marion and Washington.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Mount Vernon zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23331': {'name': 'NAD83(2011) / ICS83-Olney (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Clay, Edwards, Lawrence, Richland, Wabash and Wayne.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Olney zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23332': {'name': 'NAD83(2011) / ICS83-Carbondale (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Franklin, Gallatin, Hamilton, Jackson, Perry,  Randolph, Saline, White and Williamson.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Carbondale zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '23333': {'name': 'NAD83(2011) / ICS83-Metropolis (ftUS)',
#   'area_of_use': 'United States (USA) - Illinois - counties of Alexander, Hardin, Johnson, Massac, Pope, Pulaski and Union.',
#   'coordinate_operation': 'Illinois Coordinate System of 1983 Metropolis zone (US survey foot)',
#   'datum': 'NAD83 (National Spatial Reference System 2011)'},
#  '2334': {'name': 'Xian 1980 / Gauss-Kruger zone 20',
#   'area_of_use': 'China - onshore between 114°E and 120°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 20',
#   'datum': 'Xian 1980'},
#  '2335': {'name': 'Xian 1980 / Gauss-Kruger zone 21',
#   'area_of_use': 'China - onshore between 120°E and 126°E.',
#   'coordinate_operation': '6-degree Gauss-Kruger zone 21',
#   'datum': 'Xian 1980'},
#  ...}

# %%
epsg_codes["4326"]
# Out:
# {'name': 'WGS 84',
#  'area_of_use': 'World.',
#  'coordinate_operation': None,
#  'datum': 'World Geodetic System 1984 ensemble'}

# %%
epsg_codes["10162"]
# Out:
# {'name': 'JGD2011 / Japan Plane Rectangular CS I + JGD2011 (vertical) height',
#  'area_of_use': 'Japan - onshore - Kyushu west of approximately 130°E - Nagasaki-ken',
#  'coordinate_operation': None,
#  'datum': 'Japanese Geodetic Datum 2011'}

# %%
import json

with open("./data/epsg.json", "w") as f:
    json.dump(epsg_codes, f, ensure_ascii=False, indent=4)

# %%
# !head ./data/epsg.json
# Out:
# {
#     "10150": {
#         "name": "MSL UK & Ireland VORF08 depth",
#         "area_of_use": "Ireland and United Kingdom (UK) (including Isle of Man and Channel Islands) - inshore, nearshore and offshore.",
#         "coordinate_operation": null,
#         "datum": "Mean Sea Level UK & Ireland VORF08"
#     },
#     "10151": {
#         "name": "CD UK & Ireland VORF08 depth",
#         "area_of_use": "Ireland and United Kingdom (UK) (including Isle of Man and Channel Islands) - inshore, nearshore and offshore.",

# %% [markdown]
# ---

# %% [markdown]
# ## Appendix: epsg.org データセットからの取得
#
# ソース: https://epsg.org/home.html

# %%
wkt_paths = sorted(Path("./data/epsg/EPSG-v11_008-WKT/").glob("*.wkt"))
len(wkt_paths), wkt_paths[:5]
# Out:
# (9698,
#  [PosixPath('data/epsg/EPSG-v11_008-WKT/EPSG-CRS-10150.wkt'),
#   PosixPath('data/epsg/EPSG-v11_008-WKT/EPSG-CRS-10151.wkt'),
#   PosixPath('data/epsg/EPSG-v11_008-WKT/EPSG-CRS-10156.wkt'),
#   PosixPath('data/epsg/EPSG-v11_008-WKT/EPSG-CRS-10157.wkt'),
#   PosixPath('data/epsg/EPSG-v11_008-WKT/EPSG-CRS-10158.wkt')])

# %% [markdown]
# ### EPSG コードから pyproj で CRS を作成

# %%
epsg_codes = {}
invalid_epsg_codes = []
invalid_epsg_error_msgs = []

for p in tqdm(wkt_paths):
    stems = p.stem.split("-")
    assert stems[0] == "EPSG"
    epsg_code = int(stems[-1])

    try:
        crs = CRS.from_epsg(epsg_code)
        crs_name = crs.name
        crs_epsg = str(crs.to_epsg())
        epsg_codes[crs_epsg] = crs_name
    except Exception as e:
        invalid_epsg_codes.append(p)
        invalid_epsg_error_msgs.append(str(e))
        continue

len(epsg_codes), len(invalid_epsg_codes)
# Out:
# 100%|██████████| 9698/9698 [00:10<00:00, 890.88it/s]
# (6936, 2762)

# %%
set([msg.split("(")[1] for msg in invalid_epsg_error_msgs])
# Out:
# {'Internal Proj Error: proj_create: crs not found)'}

# %% [markdown]
# ### WKT ファイルから読み込み

# %%
epsg_codes = {}
invalid_epsg_codes = []
invalid_epsg_error_msgs = []


for p in tqdm(wkt_paths):
    with open(p) as f:
        wkt_text = f.read()
    try:
        crs = CRS.from_wkt(wkt_text)
    except Exception as e:
        invalid_epsg_codes.append(p)
        invalid_epsg_error_msgs.append(str(e))
        continue

    crs_name = crs.name
    crs_epsg = str(crs.to_epsg())
    epsg_codes[crs_epsg] = crs_name

len(epsg_codes), len(invalid_epsg_codes)
# Out:
# 100%|██████████| 9698/9698 [00:09<00:00, 1070.59it/s]
# (6550, 2690)

# %%
epsg_codes["10162"]
# Out:
# 'JGD2011 / Japan Plane Rectangular CS I + JGD2011 (vertical) height'

# %%
epsg_codes["4326"]
# Out:
# 'WGS 84'

# %% [markdown]
# ### エラーの確認

# %%
Counter([msg.split(":")[0] for msg in invalid_epsg_error_msgs])
# Out:
# Counter({'Input is not a CRS': 2677,
#          'Invalid projection': 8,
#          'Invalid WKT string': 5})

# %%
# "Input is not a CRS"
Counter(
    [
        msg.split("[")[0]
        for msg in invalid_epsg_error_msgs
        if msg.startswith("Input is not a CRS:")
    ]
)
# Out:
# Counter({'Input is not a CRS: COORDINATEOPERATION': 2491,
#          'Input is not a CRS: CONCATENATEDOPERATION': 186})

# %%
# "Invalid projection"
Counter(
    [
        msg.split("[")[0]
        for msg in invalid_epsg_error_msgs
        if msg.startswith("Invalid projection:")
    ]
)
# Out:
# Counter({'Invalid projection: DERIVEDPROJECTED': 4,
#          'Invalid projection: POINTMOTIONOPERATION': 3,
#          'Invalid projection: CONCATENATEDOPERATION': 1})

# %%
# "Invalid WKT string"
Counter(
    [msg for msg in invalid_epsg_error_msgs if msg.startswith("Invalid WKT string")]
)
# Out:
# Counter({'Invalid WKT string: WKT is not supported for vertical CRS derived in multiple steps.': 4,
#          'Invalid WKT string: POINTMOTIONOPERATION["New Caledonia velocity model 2015",SOURCECRS[GEODCRS["RGNC15",DATUM["Reseau Geodesique de Nouvelle Caledonie 2015",ELLIPSOID["GRS 1980",6378137,298.257222101,LENGTHUNIT["metre",1,ID["EPSG",9001]],ID["EPSG",7019]],ID["EPSG",1357]],CS[Cartesian,3,ID["EPSG",6500]],AXIS["Geocentric X (X)",geocentricX,LENGTHUNIT["metre",1,ID["EPSG",9001]]],AXIS["Geocentric Y (Y)",geocentricY,LENGTHUNIT["metre",1,ID["EPSG",9001]]],AXIS["Geocentric Z (Z)",geocentricZ,LENGTHUNIT["metre",1,ID["EPSG",9001]]],ID["EPSG",10308]]],METHOD["Point motion (geocen) by grid (BGN)",ID["EPSG",1120]],PARAMETERFILE["Point motion velocity grid file","grmmncl08.tac",ID["EPSG",1050]],PARAMETER["EPSG code for Interpolation CRS",10312,ID["EPSG",1048]],OPERATIONACCURACY[0.075],ID["EPSG",10323]]': 1})
